# %% [markdown]
# # Exercice: premier modèle avec scikit-learn
#
# Petits exercices pour s'entraîner sur le **contrat scikit-learn** vu dans le notebook **`02-premier-modele-sklearn`** : `X`, `y`, `train_test_split`, `.fit/.predict/.score`.
#
# On utilise cette fois le dataset **wine** : 178 vins italiens, 13 mesures chimiques par vin, à classer parmi 3 cépages (`class_0`, `class_1`, `class_2`).

# %% [markdown]
# ## Charger le dataset

# %%
# TODO : Importer load_wine depuis sklearn.datasets et charger le dataset
# dans une variable `wine`.

# %%
# TODO : Afficher la forme (.shape) de `wine.data` et `wine.target`.
# Combien de lignes ? Combien de features ? Combien de labels ?

# %%
# TODO : Afficher `wine.feature_names` et `wine.target_names`.
# Vérifier qu'on a bien 13 features et 3 classes.

# %% [markdown]
# ## Préparer X et y

# %%
# TODO : Créer les variables `X` (les features) et `y` (la cible) à partir
# de `wine.data` et `wine.target`.
# Vérifier les shapes : X doit être 2D, y doit être 1D.

# %% [markdown]
# ## Découper en train et test

# %%
# TODO : Importer train_test_split depuis sklearn.model_selection.
# Découper X et y en (X_train, X_test, y_train, y_test) avec :
#   - test_size = 0.25
#   - random_state = 0
# Afficher les shapes obtenues.

# %% [markdown]
# ## Baseline avec DummyClassifier

# %%
# TODO : Importer DummyClassifier depuis sklearn.dummy.
# Créer un DummyClassifier avec strategy="most_frequent".
# L'entraîner sur (X_train, y_train) et afficher son score sur (X_test, y_test).
# Que vaut le plancher ?

# %% [markdown]
# ## KNeighborsClassifier

# %%
# TODO : Importer KNeighborsClassifier depuis sklearn.neighbors.
# Créer un KNeighborsClassifier avec n_neighbors=1.
# L'entraîner et afficher son score sur le test.
# Bat-il la baseline ?

# %% [markdown]
# ## predict et predict_proba

# %%
# TODO : Avec le modèle KNN entraîné, prédire la classe des 5 premiers
# vins de test (X_test[:5]). Comparer avec y_test[:5].

# %%
# TODO : Afficher les probabilités prédites pour ces mêmes 5 vins
# avec .predict_proba(). À quoi ressemblent-elles avec n_neighbors=1 ?

# %% [markdown]
# ## Bonus — Influence du `random_state`

# %%
# TODO : Refaire le split avec random_state=1, ré-entraîner le KNN,
# et afficher le nouveau score. Le score est-il identique ?
# Que vous apprend ça sur la fiabilité d'un score unique ?
