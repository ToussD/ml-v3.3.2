# %% [markdown]
# # Exercice: numpy
#
# Voir le [User Guide](https://numpy.org/doc/stable/user/absolute_beginners.html#) de numpy

# %%
import numpy as np

# %% [markdown]
# ## Tests

# %%
# TODO: Ecrire une fonction vérifiant si un tableau contient au moins un élément différent de 0

# %%
# TODO: Ecrire une fonction vérifiant qu'un tableau ne possède pas de valeurs nulles. On pourra utiliser la fonction np.isnan

# %% [markdown]
# ## Création de tableaux

# %%
# TODO: Créer trois tableaux contenant dix 0, dix 1 et dix 5

# %%
# TODO: créer une matrice identité de 3 x 3

# %%
# TODO: Creer un tableau de nombres de 30 à 70

# %%
# TODO: Creer un tableau de nombres pairs de 30 à 70

# %% [markdown]
# ## Opérations sur les tableaux

# %%
# TODO : multiplier tous les membres d'un tableau par 5

# %%
# TODO : comparer deux vecteurs de même dimension membre à membre pour vérifier s'ils sont identiques.

# %% [markdown]
# ## Nombres aléatoires
#
# Consulter la documentation de [Generator](https://numpy.org/doc/stable/reference/random/generator.html). En particulier, étudiez les fonctions de génération disponibles

# %%
# On crée un générateur de nombres aléatoires (Generator)

rng = np.random.default_rng(0)

# %% [markdown]
# ---
# Voir la [documentation](https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.random.html)

# %%
# TODO: Générer un nombre aléatoire entre entre 0 et 1

# %% [markdown]
# ---
#
# Voir la [documentation](https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.integers.html)

# %%
# TODO: Générer un vecteur de 10 entiers aléatoires entre 9 et 20

# %% [markdown]
# ---
#
# Voir la [documentation](https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.normal.html)

# %%
# TODO: Générer un tableau x de 15 nombres aléatoires d'une distribution normale

# %%
# TODO: Transformer le tableau x précédent en matrice 3 x 5
